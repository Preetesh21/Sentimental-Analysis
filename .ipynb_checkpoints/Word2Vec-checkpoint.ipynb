# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import state_union
from nltk.stem import WordNetLemmatizer

# %%
lemma=WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# %%
text1=state_union.raw('2005-GWBush.txt')

# %%
text1
# Out:
# 'PRESIDENT GEORGE W. BUSH\'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nFebruary 2, 2005\n\n\n9:10 P.M. EST \n\nTHE PRESIDENT: Mr. Speaker, Vice President Cheney, members of Congress, fellow citizens: \n\nAs a new Congress gathers, all of us in the elected branches of government share a great privilege: We\'ve been placed in office by the votes of the people we serve. And tonight that is a privilege we share with newly-elected leaders of Afghanistan, the Palestinian Territories, Ukraine, and a free and sovereign Iraq. (Applause.) \n\nTwo weeks ago, I stood on the steps of this Capitol and renewed the commitment of our nation to the guiding ideal of liberty for all. This evening I will set forth policies to advance that ideal at home and around the world. \n\nTonight, with a healthy, growing economy, with more Americans going back to work, with our nation an active force for good in the world -- the state of our union is confident and strong. (Applause.) \n\nOur generation has been blessed -- by the expansion of opportunity, by advances in medicine, by the security purchased by our parents\' sacrifice. Now, as we see a little gray in the mirror -- or a lot of gray -- (laughter) -- and we watch our children moving into adulthood, we ask the question: What will be the state of their union? Members of Congress, the choices we make together will answer that question. Over the next several months, on issue after issue, let us do what Americans have always done, and build a better world for our children and our grandchildren. (Applause.) \n\nFirst, we must be good stewards of this economy, and renew the great institutions on which millions of our fellow citizens rely. America\'s economy is the fastest growing of any major industrialized nation. In the past four years, we provided tax relief to every person who pays income taxes, overcome a recession, opened up new markets abroad, prosecuted corporate criminals, raised homeownership to its highest level in history, and in the last year alone, the United States has added 2.3 million new jobs. (Applause.) When action was needed, the Congress delivered -- and the nation is grateful. \n\nNow we must add to these achievements. By making our economy more flexible, more innovative, and more competitive, we will keep America the economic leader of the world. (Applause.) \n\nAmerica\'s prosperity requires restraining the spending appetite of the federal government. I welcome the bipartisan enthusiasm for spending discipline. I will send you a budget that holds the growth of discretionary spending below inflation, makes tax relief permanent, and stays on track to cut the deficit in half by 2009. (Applause.) My budget substantially reduces or eliminates more than 150 government programs that are not getting results, or duplicate current efforts, or do not fulfill essential priorities. The principle here is clear: Taxpayer dollars must be spent wisely, or not at all. (Applause.) \n\nTo make our economy stronger and more dynamic, we must prepare a rising generation to fill the jobs of the 21st century. Under the No Child Left Behind Act, standards are higher, test scores are on the rise, and we\'re closing the achievement gap for minority students. Now we must demand better results from our high schools, so every high school diploma is a ticket to success. We will help an additional 200,000 workers to get training for a better career, by reforming our job training system and strengthening America\'s community colleges. And we\'ll make it easier for Americans to afford a college education, by increasing the size of Pell Grants. (Applause.) \n\nTo make our economy stronger and more competitive, America must reward, not punish, the efforts and dreams of entrepreneurs. Small business is the path of advancement, especially for women and minorities, so we must free small businesses from needless regulation and protect honest job-creators from junk lawsuits. (Applause.)  ...

# %%
words_token=word_tokenize(text1)

# %%
words_token=[w.lower() for w in words_token]
words_token=[w for w in words_token if w.isalpha()]
words_token=[w for w in words_token if not w in stop_words]
words_token=[lemma.lemmatize(w) for w in words_token]

# %%
from wordcloud import WordCloud
plt.figure(figsize = (20,20)) # Text Reviews with Poor Ratings
wc = WordCloud(min_font_size = 3,  max_words = 2000 , width = 1600 , height = 800).generate(" ".join(words_token))
plt.imshow(wc,interpolation = 'bilinear')

# %%
import keras
from keras.preprocessing import text
from keras.utils import np_utils
from keras.preprocessing import sequence
from keras.layers import *
import keras.backend as K
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(words_token)
word2id = tokenizer.word_index

# build vocabulary of unique words
word2id['PAD'] = 0
id2word = {v:k for k, v in word2id.items()}
wids=[word2id[w] for w in words_token]

vocab_size = len(word2id)
embed_size = 100
window_size = 2 # context window size

print('Vocabulary Size:', vocab_size)
print('Vocabulary Sample:', list(word2id.items())[:10])
# Out:
# Vocabulary Size: 1203
# Vocabulary Sample: [('applause', 1), ('security', 2), ('must', 3), ('make', 4), ('year', 5), ('freedom', 6), ('america', 7), ('country', 8), ('government', 9), ('people', 10)]

# %%
def generates(corpus,window_size,vocab_size):
    context_length = window_size*2
    
    for index, word in enumerate(corpus):
        context_words = []
        label_word   = []            
        start = index - window_size
        end = index + window_size + 1
        context_words.append([corpus[i] 
                             for i in range(start, end)
                             if 0 <= i < len(corpus) 
                                 and i != index])
        label_word.append(word)

        x = sequence.pad_sequences(context_words, maxlen=context_length)
        y = np_utils.to_categorical(label_word, vocab_size)
        #print(context_words)
        yield (x, y)

# %%
i = 0
for x, y in generates(corpus=wids, window_size=window_size, vocab_size=vocab_size):
    if 0 not in x[0]:
        print('Context (X):', [id2word[w] for w in x[0]], '-> Target (Y):', id2word[np.argwhere(y[0])[0][0]])
    
        if i == 10:
            break
        i += 1
# Out:
# Context (X): ['president', 'george', 'address', 'joint'] -> Target (Y): bush
# Context (X): ['george', 'bush', 'joint', 'session'] -> Target (Y): address
# Context (X): ['bush', 'address', 'session', 'congress'] -> Target (Y): joint
# Context (X): ['address', 'joint', 'congress', 'state'] -> Target (Y): session
# Context (X): ['joint', 'session', 'state', 'union'] -> Target (Y): congress
# Context (X): ['session', 'congress', 'union', 'february'] -> Target (Y): state
# Context (X): ['congress', 'state', 'february', 'est'] -> Target (Y): union
# Context (X): ['state', 'union', 'est', 'president'] -> Target (Y): february
# Context (X): ['union', 'february', 'president', 'speaker'] -> Target (Y): est
# Context (X): ['february', 'est', 'speaker', 'vice'] -> Target (Y): president
# Context (X): ['est', 'president', 'vice', 'president'] -> Target (Y): speaker

# %%
cbow = Sequential()
cbow.add(Embedding(input_dim=vocab_size, output_dim=embed_size, input_length=window_size*2))
cbow.add(Lambda(lambda x: K.mean(x, axis=1), output_shape=(embed_size,)))
cbow.add(Dense(vocab_size, activation='softmax'))

cbow.compile(loss='categorical_crossentropy', optimizer='rmsprop')
print(cbow.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 4, 100)            120300
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1203)              121503
# =================================================================
# Total params: 241,803
# Trainable params: 241,803
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
for epoch in range(1, 6):
    loss = 0.
    i = 0
    for x, y in generates(corpus=wids, window_size=window_size, vocab_size=vocab_size):
        i += 1
        loss += cbow.train_on_batch(x, y)
        if i % 1000 == 0:
            print('Processed {} (context, word) pairs'.format(i))

    print('Epoch:', epoch, '\tLoss:', loss)
    print()
# Out:
# C:\Anaconda\anaconda3\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Processed 1000 (context, word) pairs
# Processed 2000 (context, word) pairs
# Epoch: 1 	Loss: 19020.45782852173
#
# Processed 1000 (context, word) pairs
# Processed 2000 (context, word) pairs
# Epoch: 2 	Loss: 18327.94499731064
#
# Processed 1000 (context, word) pairs
# Processed 2000 (context, word) pairs
# Epoch: 3 	Loss: 17894.292060375214
#
# Processed 1000 (context, word) pairs
# Processed 2000 (context, word) pairs
# Epoch: 4 	Loss: 17693.16949224472
#
# Processed 1000 (context, word) pairs
# Processed 2000 (context, word) pairs
# Epoch: 5 	Loss: 17785.511780321598

# %%
weights = cbow.get_weights()[0]
weights = weights[1:]
print(weights.shape)

pd.DataFrame(weights, index=list(id2word.values())[1:]).head()
# Out:
# (1202, 100)
#                 0         1         2         3         4         5   \
# security -0.035491  0.030570 -0.187189  0.227531  0.151827 -0.183698
# must     -0.052842 -0.135452  0.277220  0.081061 -0.174168  0.023801
# make      0.173231  0.086261  0.014303 -0.027175  0.163990 -0.108136
# year     -0.017433 -0.058877 -0.028560 -0.000524 -0.013447 -0.078482
# freedom   0.012870 -0.134808 -0.012797  0.018575 -0.073448 -0.135916
#
#                 6         7         8         9   ...        90        91  \
# security -0.067298  0.099851 -0.031707  0.069574  ... -0.172066 -0.010675
# must     -0.018321 -0.073881  0.107465 -0.150568  ... -0.144151 -0.234389
# make      0.106412 -0.066336  0.028361  0.088093  ...  0.036396 -0.144159
# year      0.143638 -0.054695  0.012488 -0.105074  ...  0.232776  0.125519
# freedom  -0.093748  0.035701  0.153178 -0.305149  ... -0.009182  0.172439
#
#                 92        93        94        95        96        97  \
# security  0.127404  0.032716  0.149154  0.338538 -0.104993  0.075416
# must     -0.039821 -0.179372  0.047589  0.135413  0.076980 -0.219931
# make      0.108255  0.011165  0.023539  0.237029 -0.088461  0.011405
# year      0.036631  0.016369 -0.162412  0.143614  0.054632  0.242809
# freedom  -0.073897 -0.336387 -0.048543  0.184436  0.155979  0.164023
#
#                 98        99
# security  0.086642 -0.057845
# must      0.136919 -0.266143
# make      0.131998  0.002544
# year      0.260233  0.074642
# freedom  -0.238718 -0.152891
#
# [5 rows x 100 columns]

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=3)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(weights)
labels = list(id2word.values())

plt.figure(figsize=(24, 14))
plt.scatter(T[:80, 0], T[:80, 1], c='steelblue', edgecolors='k')
for label, x, y in zip(labels, T[:80, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
from gensim.models import word2vec

x=[]
x.append([w for w in words_token])

# Set values for various parameters
feature_size = 100    # Word vector dimensionality  
window_context = 5          # Context window size                                                                                    
min_word_count = 1   # Minimum word count                        
sample = 1e-3   # Downsample setting for frequent words

w2v_model = word2vec.Word2Vec(x, size=feature_size, 
                          window=window_context, min_count=min_word_count,
                          sample=sample, iter=50)

# %%
w2v_model.similarity('terror','terrorist')
# Out:
# C:\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.99992305

# %%
model2_skip = gensim.models.Word2Vec(x, min_count = 1, size = 100, 
                                             window = 5,iter=50, sg = 1)

# %%
model2_skip.similarity('terror','terrorist')
# Out:
# C:\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9320787

# %%
words = w2v_model.wv.index2word
wvs = w2v_model.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(24, 14))
plt.scatter(T[:40, 0], T[:40, 1], c='orange', edgecolors='r')
for label, x, y in zip(labels, T[:40, 0], T[:40, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
words =model2_skip.wv.index2word
wvs = model2_skip.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=5000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(24, 14))
plt.scatter(T[:40, 0], T[:40, 1], c='orange', edgecolors='r')
for label, x, y in zip(labels, T[:40, 0], T[:40, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
words_token
# Out:
# ['president',
#  'george',
#  'bush',
#  'address',
#  'joint',
#  'session',
#  'congress',
#  'state',
#  'union',
#  'february',
#  'est',
#  'president',
#  'speaker',
#  'vice',
#  'president',
#  'cheney',
#  'member',
#  'congress',
#  'fellow',
#  'citizen',
#  'new',
#  'congress',
#  'gather',
#  'u',
#  'elected',
#  'branch',
#  'government',
#  'share',
#  'great',
#  'privilege',
#  'placed',
#  'office',
#  'vote',
#  'people',
#  'serve',
#  'tonight',
#  'privilege',
#  'share',
#  'leader',
#  'afghanistan',
#  'palestinian',
#  'territory',
#  'ukraine',
#  'free',
#  'sovereign',
#  'iraq',
#  'applause',
#  'two',
#  'week',
#  'ago',
#  'stood',
#  'step',
#  'capitol',
#  'renewed',
#  'commitment',
#  'nation',
#  'guiding',
#  'ideal',
#  'liberty',
#  'evening',
#  'set',
#  'forth',
#  'policy',
#  'advance',
#  'ideal',
#  'home',
#  'around',
#  'world',
#  'tonight',
#  'healthy',
#  'growing',
#  'economy',
#  'american',
#  'going',
#  'back',
#  'work',
#  'nation',
#  'active',
#  'force',
#  'good',
#  'world',
#  'state',
#  'union',
#  'confident',
#  'strong',
#  'applause',
#  'generation',
#  'blessed',
#  'expansion',
#  'opportunity',
#  'advance',
#  'medicine',
#  'security',
#  'purchased',
#  'parent',
#  'sacrifice',
#  'see',
#  'little',
#  'gray',
#  'mirror',
#  'lot',
#  'gray',
#  'laughter',
#  'watch',
#  'child',
#  'moving',
#  'adulthood',
#  'ask',
#  'question',
#  'state',
#  'union',
#  'member',
#  'congress',
#  'choice',
#  'make',
#  'together',
#  'answer',
#  'question',
#  'next',
#  'several',
#  'month',
#  'issue',
#  'issue',
#  'let',
#  'u',
#  'american',
#  'always',
#  'done',
#  'build',
#  'better',
#  'world',
#  'child',
#  'grandchild',
#  'applause',
#  'first',
#  'must',
#  'good',
#  'steward',
#  'economy',
#  'renew',
#  'great',
#  'institution',
#  'million',
#  'fellow',
#  'citizen',
#  'rely',
#  'america',
#  'economy',
#  'fastest',
#  'growing',
#  'major',
#  'industrialized',
#  'nation',
#  'past',
#  'four',
#  'year',
#  'provided',
#  'tax',
#  'relief',
#  'every',
#  'person',
#  'pay',
#  'income',
#  'tax',
#  'overcome',
#  'recession',
#  'opened',
#  'new',
#  'market',
#  'abroad',
#  'prosecuted',
#  'corporate',
#  'criminal',
#  'raised',
#  'homeownership',
#  'highest',
#  'level',
#  'history',
#  'last',
#  'year',
#  'alone',
#  'united',
#  'state',
#  'added',
#  'million',
#  'new',
#  'job',
#  'applause',
#  'action',
#  'needed',
#  'congress',
#  'delivered',
#  'nation',
#  'grateful',
#  'must',
#  'add',
#  'achievement',
#  'making',
#  'economy',
#  'flexible',
#  'innovative',
#  'competitive',
#  'keep',
#  'america',
#  'economic',
#  'leader',
#  'world',
#  'applause',
#  'america',
#  'prosperity',
#  'requires',
#  'restraining',
#  'spending',
#  'appetite',
#  'federal',
#  'government',
#  'welcome',
#  'bipartisan',
#  'enthusiasm',
#  'spending',
#  'discipline',
#  'send',
#  'budget',
#  'hold',
#  'growth',
#  'discretionary',
#  'spending',
#  'inflation',
#  'make',
#  'tax',
#  'relief',
#  'permanent',
#  'stay',
#  'track',
#  'cut',
#  'deficit',
#  'half',
#  'applause',
#  'budget',
#  'substantially',
#  'reduces',
#  'eliminates',
#  'government',
#  'program',
#  'getting',
#  'result',
#  'duplicate',
#  'current',
#  'effort',
#  'fulfill',
#  'essential',
#  'priority',
#  'principle',
#  'clear',
#  'taxpayer',
#  'dollar',
#  'must',
#  'spent',
#  'wisely',
#  'applause',
#  'make',
#  'economy',
#  'stronger',
#  'dynamic',
#  'must',
#  'prepare',
#  'rising',
#  'generation',
#  'fill',
#  'job',
#  'century',
#  'child',
#  'left',
#  'behind',
#  'act',
#  'standard',
#  'higher',
#  'test',
#  'score',
#  'rise',
#  'closing',
#  'achievement',
#  'gap',
#  'minority',
#  'student',
#  'must',
#  'demand',
#  'better',
#  'result',
#  'high',
#  'school',
#  'every',
#  'high',
#  'school',
#  'diploma',
#  'ticket',
#  'success',
#  'help',
#  'additional',
#  'worker',
#  'get',
#  'training',
#  'better',
#  'career',
#  'reforming',
#  'job',
#  'training',
#  'system',
#  'strengthening',
#  'america',
#  'community',
#  'college',
#  'make',
#  'easier',
#  'american',
#  'afford',
#  'college',
#  'education',
#  'increasing',
#  'size',
#  'pell',
#  'grant',
#  'applause',
#  'make',
#  'economy',
#  'stronger',
#  'competitive',
#  'america',
#  'must',
#  'reward',
#  'punish',
#  'effort',
#  'dream',
#  'entrepreneur',
#  'small',
#  'business',
#  'path',
#  'advancement',
#  'especially',
#  'woman',
#  'minority',
#  'must',
#  'free',
#  'small',
#  'business',
#  'needle',
#  'regulation',
#  'protect',
#  'honest',
#  'junk',
#  'lawsuit',
#  'applause',
#  'justice',
#  'distorted',
#  'economy',
#  'held',
#  'back',
#  'irresponsible',
#  'frivolous',
#  'asbestos',
#  'claim',
#  'urge',
#  'congress',
#  'pas',
#  'legal',
#  'reform',
#  'year',
#  'applause',
#  'make',
#  'economy',
#  'stronger',
#  'productive',
#  'must',
#  'make',
#  'health',
#  'care',
#  'affordable',
#  'give',
#  'family',
#  'greater',
#  'access',
#  'good',
#  'coverage',
#  'applause',
#  'control',
#  'health',
#  'decision',
#  'applause',
#  'ask',
#  'congress',
#  'move',
#  'forward',
#  'comprehensive',
#  'health',
#  'care',
#  'agenda',
#  'tax',
#  'credit',
#  'help',
#  'worker',
#  'buy',
#  'insurance',
#  'community',
#  'health',
#  'center',
#  'every',
#  'poor',
#  'country',
#  'improved',
#  'information',
#  'technology',
#  'prevent',
#  'medical',
#  'error',
#  'needle',
#  'cost',
#  'association',
#  'health',
#  'plan',
#  'small',
#  'business',
#  'employee',
#  'applause',
#  'expanded',
#  'health',
#  'saving',
#  'account',
#  'applause',
#  'medical',
#  'liability',
#  'reform',
#  'reduce',
#  'health',
#  'care',
#  'cost',
#  'make',
#  'sure',
#  'patient',
#  'doctor',
#  'care',
#  'need',
#  'applause',
#  'keep',
#  'economy',
#  'growing',
#  'also',
#  'need',
#  'reliable',
#  'supply',
#  'affordable',
#  'environmentally',
#  'responsible',
#  'energy',
#  'applause',
#  'nearly',
#  'four',
#  'year',
#  'ago',
#  'submitted',
#  'comprehensive',
#  'energy',
#  'strategy',
#  'encourages',
#  'conservation',
#  'alternative',
#  'source',
#  'modernized',
#  'electricity',
#  'grid',
#  'production',
#  'home',
#  'including',
#  'safe',
#  'clean',
#  'nuclear',
#  'energy',
#  'applause',
#  'clear',
#  'sky',
#  'legislation',
#  'cut',
#  'power',
#  'plant',
#  'pollution',
#  'improve',
#  'health',
#  'citizen',
#  'applause',
#  'budget',
#  'provides',
#  'strong',
#  'funding',
#  'technology',
#  'car',
#  'clean',
#  'coal',
#  'renewable',
#  'source',
#  'ethanol',
#  'applause',
#  'four',
#  'year',
#  'debate',
#  'enough',
#  'urge',
#  'congress',
#  'pas',
#  'legislation',
#  'make',
#  'america',
#  'secure',
#  'le',
#  'dependent',
#  'foreign',
#  'energy',
#  'applause',
#  'proposal',
#  'essential',
#  'expand',
#  'economy',
#  'add',
#  'new',
#  'job',
#  'beginning',
#  'duty',
#  'build',
#  'prosperity',
#  'future',
#  'generation',
#  'must',
#  'update',
#  'institution',
#  'created',
#  'meet',
#  'need',
#  'earlier',
#  'time',
#  'year',
#  'year',
#  'american',
#  'burdened',
#  'archaic',
#  'incoherent',
#  'federal',
#  'tax',
#  'code',
#  'appointed',
#  'bipartisan',
#  'panel',
#  'examine',
#  'tax',
#  'code',
#  'top',
#  'bottom',
#  'recommendation',
#  'delivered',
#  'work',
#  'together',
#  'give',
#  'nation',
#  'tax',
#  'code',
#  'easy',
#  'understand',
#  'fair',
#  'applause',
#  'america',
#  'immigration',
#  'system',
#  'also',
#  'outdated',
#  'unsuited',
#  'need',
#  'economy',
#  'value',
#  'country',
#  'content',
#  'law',
#  'punish',
#  'hardworking',
#  'people',
#  'want',
#  'provide',
#  'family',
#  'deny',
#  'business',
#  'willing',
#  'worker',
#  'invite',
#  'chaos',
#  'border',
#  'time',
#  'immigration',
#  'policy',
#  'permit',
#  'temporary',
#  'guest',
#  'worker',
#  'fill',
#  'job',
#  'american',
#  'take',
#  'reject',
#  'amnesty',
#  'tell',
#  'u',
#  'entering',
#  'leaving',
#  'country',
#  'close',
#  'border',
#  'drug',
#  'dealer',
#  'terrorist',
#  'applause',
#  'one',
#  'america',
#  'important',
#  'institution',
#  'symbol',
#  'trust',
#  'generation',
#  'also',
#  'need',
#  'wise',
#  'effective',
#  'reform',
#  'social',
#  'security',
#  'great',
#  'moral',
#  'success',
#  'century',
#  'must',
#  'honor',
#  'great',
#  'purpose',
#  'new',
#  'century',
#  'applause',
#  'system',
#  'however',
#  'current',
#  'path',
#  'headed',
#  'toward',
#  'bankruptcy',
#  'must',
#  'join',
#  'together',
#  'strengthen',
#  'save',
#  'social',
#  'security',
#  'applause',
#  'today',
#  'million',
#  'american',
#  'receive',
#  'social',
#  'security',
#  'benefit',
#  'million',
#  'nearing',
#  'retirement',
#  'system',
#  'sound',
#  'fiscally',
#  'strong',
#  'message',
#  'every',
#  'american',
#  'older',
#  'let',
#  'anyone',
#  'mislead',
#  'social',
#  'security',
#  'system',
#  'change',
#  'way',
#  'applause',
#  'younger',
#  'worker',
#  'social',
#  'security',
#  'system',
#  'serious',
#  'problem',
#  'grow',
#  'worse',
#  'time',
#  'social',
#  'security',
#  'created',
#  'decade',
#  'ago',
#  'different',
#  'era',
#  'day',
#  'people',
#  'live',
#  'long',
#  'benefit',
#  'much',
#  'lower',
#  'today',
#  'ago',
#  'sixteen',
#  'worker',
#  'paid',
#  'system',
#  'person',
#  'drawing',
#  'benefit',
#  'society',
#  'changed',
#  'way',
#  'founder',
#  'social',
#  'security',
#  'could',
#  'foreseen',
#  'today',
#  'world',
#  'people',
#  'living',
#  'longer',
#  'therefore',
#  'drawing',
#  'benefit',
#  'longer',
#  'benefit',
#  'scheduled',
#  'rise',
#  'dramatically',
#  'next',
#  'decade',
#  'instead',
#  'sixteen',
#  'worker',
#  'paying',
#  'every',
#  'beneficiary',
#  'right',
#  'three',
#  'worker',
#  'next',
#  'decade',
#  'number',
#  'fall',
#  'two',
#  'worker',
#  'per',
#  'beneficiary',
#  'passing',
#  'year',
#  'fewer',
#  'worker',
#  'paying',
#  'benefit',
#  'number',
#  'retiree',
#  'result',
#  'thirteen',
#  'year',
#  'social',
#  'security',
#  'paying',
#  'take',
#  'every',
#  'year',
#  'afterward',
#  'bring',
#  'new',
#  'shortfall',
#  'bigger',
#  'year',
#  'example',
#  'year',
#  'government',
#  'somehow',
#  'come',
#  'extra',
#  'billion',
#  'keep',
#  'system',
#  'afloat',
#  'annual',
#  'shortfall',
#  'would',
#  'billion',
#  'year',
#  'entire',
#  'system',
#  'would',
#  'exhausted',
#  'bankrupt',
#  'step',
#  'taken',
#  'avert',
#  'outcome',
#  'solution',
#  'would',
#  'dramatically',
#  'higher',
#  'tax',
#  'massive',
#  'new',
#  'borrowing',
#  'sudden',
#  'severe',
#  'cut',
#  'social',
#  'security',
#  'benefit',
#  'government',
#  'program',
#  'recognize',
#  'may',
#  'seem',
#  'long',
#  'way',
#  'date',
#  'distant',
#  'parent',
#  'tell',
#  'already',
#  'concerned',
#  'pay',
#  'college',
#  'tuition',
#  'year',
#  'road',
#  'got',
#  'child',
#  'u',
#  'idea',
#  'social',
#  'security',
#  'collapsing',
#  'retire',
#  'seem',
#  'like',
#  'small',
#  'matter',
#  'small',
#  'matter',
#  'united',
#  'state',
#  'congress',
#  'applause',
#  'share',
#  'responsibility',
#  'must',
#  'pas',
#  'reform',
#  'solve',
#  'financial',
#  'problem',
#  'social',
#  'security',
#  'fixing',
#  'social',
#  'security',
#  'permanently',
#  'require',
#  'open',
#  'candid',
#  'review',
#  'option',
#  'suggested',
#  'limiting',
#  'benefit',
#  'wealthy',
#  'retiree',
#  'former',
#  'congressman',
#  'tim',
#  'penny',
#  'raised',
#  'possibility',
#  'indexing',
#  'benefit',
#  'price',
#  'rather',
#  'wage',
#  'predecessor',
#  'president',
#  'clinton',
#  'spoke',
#  'increasing',
#  'retirement',
#  'age',
#  'former',
#  'senator',
#  'john',
#  'breaux',
#  'suggested',
#  'discouraging',
#  'early',
#  'collection',
#  'social',
#  'security',
#  'benefit',
#  'late',
#  'senator',
#  'daniel',
#  'patrick',
#  'moynihan',
#  'recommended',
#  'changing',
#  'way',
#  'benefit',
#  'calculated',
#  'idea',
#  'table',
#  'know',
#  'none',
#  'reform',
#  'would',
#  'easy',
#  'move',
#  'ahead',
#  'courage',
#  'honesty',
#  'child',
#  'retirement',
#  'security',
#  'important',
#  'partisan',
#  'politics',
#  'applause',
#  'work',
#  'member',
#  'congress',
#  'find',
#  'effective',
#  'combination',
#  'reform',
#  'listen',
#  'anyone',
#  'good',
#  'idea',
#  'offer',
#  'applause',
#  'must',
#  'however',
#  'guided',
#  'basic',
#  'principle',
#  'must',
#  'make',
#  'social',
#  'security',
#  'permanently',
#  'sound',
#  'leave',
#  'task',
#  'another',
#  'day',
#  'must',
#  'jeopardize',
#  'economic',
#  'strength',
#  'increasing',
#  'payroll',
#  'tax',
#  'must',
#  'ensure',
#  'american',
#  'get',
#  'help',
#  'need',
#  'dignity',
#  'peace',
#  'mind',
#  'retirement',
#  'must',
#  'guarantee',
#  'change',
#  'retired',
#  'nearing',
#  'retirement',
#  'must',
#  'take',
#  'care',
#  'change',
#  'system',
#  'gradual',
#  'younger',
#  'worker',
#  'year',
#  'prepare',
#  'plan',
#  'future',
#  'fix',
#  'social',
#  'security',
#  'also',
#  ...]
